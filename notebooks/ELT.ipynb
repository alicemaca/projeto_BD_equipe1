# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\figue\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\figue\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\figue\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

usuario_db = 'postgres'
senha_db = 'rai123'
host_db = 'localhost'
porta_db = '5432'
nome_banco_db = 'transformacao_enem'

DATABASE_URL = f'postgresql://{usuario_db}:{senha_db}@{host_db}:{porta_db}/{nome_banco_db}'
engine = create_engine(DATABASE_URL)

print("Conexão criada.")

arquivos_brutos = {
    'MICRODADOS_ENEM_2021': 'dados/MICRODADOS_ENEM_2021_CORTADO.csv',
    'MICRODADOS_ENEM_2022': 'dados/MICRODADOS_ENEM_2022_CORTADO.csv',
    'MICRODADOS_ENEM_2023': 'dados/MICRODADOS_ENEM_2023_CORTADO.csv'
}
# Out:
# Conexão criada.

# %%
print("Iniciando carga dos dados BRUTOS...")

for nome_tabela, caminho_arquivo in arquivos_brutos.items():
    try:
        print(f"Lendo o arquivo: {caminho_arquivo}")
        df_raw = pd.read_csv(
            caminho_arquivo, 
            encoding='utf-8',
            on_bad_lines='skip' 
        )
        
        print(f"Carregando {len(df_raw)} linhas brutos na tabela: {nome_tabela}...")
        
        df_raw.to_sql(
            nome_tabela,
            con=engine,
            if_exists='replace',
            index=False
        )
        print(f"Tabela {nome_tabela} carregada com sucesso.")
        
    except Exception as e:
        print(f"Erro ao processar {caminho_arquivo}: {e}")

print("\nProcesso de EL (Extração e Carga) concluído.")
# Out:
# Iniciando carga dos dados BRUTOS...
# Lendo o arquivo: dados/MICRODADOS_ENEM_2021_CORTADO.csv
# Carregando 200000 linhas brutos na tabela: MICRODADOS_ENEM_2021...
# Tabela MICRODADOS_ENEM_2021 carregada com sucesso.
# Lendo o arquivo: dados/MICRODADOS_ENEM_2022_CORTADO.csv
# Carregando 200000 linhas brutos na tabela: MICRODADOS_ENEM_2022...
# Tabela MICRODADOS_ENEM_2022 carregada com sucesso.
# Lendo o arquivo: dados/MICRODADOS_ENEM_2023_CORTADO.csv
# Carregando 200000 linhas brutos na tabela: MICRODADOS_ENEM_2023...
# Tabela MICRODADOS_ENEM_2023 carregada com sucesso.
#
# Processo de EL (Extração e Carga) concluído.

# %%
pip install dbt-postgres
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\figue\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
