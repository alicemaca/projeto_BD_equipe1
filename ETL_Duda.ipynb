# %% [markdown]
# ## **Importando dados do drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Instalando e importando a biblioteca Pandas**

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %% [markdown]
# ## **Extraindo os dados**

# %%
caminho_2021 = '/content/drive/MyDrive/dados/MICRODADOS_ENEM_2021_CORTADO.csv'
caminho_2022 = '/content/drive/MyDrive/dados/MICRODADOS_ENEM_2022_CORTADO.csv'
caminho_2023 = '/content/drive/MyDrive/dados/MICRODADOS_ENEM_2023_CORTADO.csv'
arquivos = {
    '2021': caminho_2021,
    '2022': caminho_2022,
    '2023': caminho_2023
}

lista_dataframes = []

for ano, arquivo in arquivos.items():
    try:
        df = pd.read_csv(arquivo, encoding='latin-1', sep=',')
        lista_dataframes.append(df)
    except Exception as e:
        print(f"Erro ao ler os dados do ano {ano}: {e}")

df = pd.concat(lista_dataframes, ignore_index=True)

# %% [markdown]
# ## **Visualização geral**

# %%
display(df.head(5))
display(df.info())
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# 0  ...     A     A     A    B     A    A     B     A     B     B
# 1  ...     A     A     A    B     A    A     C     A     A     A
# 2  ...     B     A     A    B     A    A     C     B     B     B
# 3  ...     A     A     A    B     A    A     B     A     B     B
# 4  ...     B     A     A    B     A    B     E     A     B     B
#
# [5 rows x 76 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   NU_INSCRICAO            600000 non-null  int64
#  1   NU_ANO                  600000 non-null  int64
#  2   TP_FAIXA_ETARIA         600000 non-null  int64
#  3   TP_SEXO                 600000 non-null  object
#  4   TP_ESTADO_CIVIL         600000 non-null  int64
#  5   TP_COR_RACA             600000 non-null  int64
#  6   TP_NACIONALIDADE        600000 non-null  int64
#  7   TP_ST_CONCLUSAO         600000 non-null  int64
#  8   TP_ANO_CONCLUIU         600000 non-null  int64
#  9   TP_ESCOLA               600000 non-null  int64
#  10  TP_ENSINO               238926 non-null  float64
#  11  IN_TREINEIRO            600000 non-null  int64
#  12  CO_MUNICIPIO_ESC        152097 non-null  float64
#  13  NO_MUNICIPIO_ESC        152097 non-null  object
#  14  CO_UF_ESC               152097 non-null  float64
#  15  SG_UF_ESC               152097 non-null  object
#  16  TP_DEPENDENCIA_ADM_ESC  152097 non-null  float64
#  17  TP_LOCALIZACAO_ESC      152097 non-null  float64
#  18  TP_SIT_FUNC_ESC         152097 non-null  float64
#  19  CO_MUNICIPIO_PROVA      600000 non-null  int64
#  20  NO_MUNICIPIO_PROVA      600000 non-null  object
#  21  CO_UF_PROVA             600000 non-null  int64
#  22  SG_UF_PROVA             600000 non-null  object
#  23  TP_PRESENCA_CN          600000 non-null  int64
#  24  TP_PRESENCA_CH          600000 non-null  int64
#  25  TP_PRESENCA_LC          600000 non-null  int64
#  26  TP_PRESENCA_MT          600000 non-null  int64
#  27  CO_PROVA_CN             449009 non-null  float64
#  28  CO_PROVA_CH             469211 non-null  float64
#  29  CO_PROVA_LC             469211 non-null  float64
#  30  CO_PROVA_MT             449009 non-null  float64
#  31  NU_NOTA_CN              449009 non-null  float64
#  32  NU_NOTA_CH              469211 non-null  float64
#  33  NU_NOTA_LC              469211 non-null  float64
#  34  NU_NOTA_MT              449009 non-null  float64
#  35  TX_RESPOSTAS_CN         449009 non-null  object
#  36  TX_RESPOSTAS_CH         469211 non-null  object
#  37  TX_RESPOSTAS_LC         469211 non-null  object
#  38  TX_RESPOSTAS_MT         449009 non-null  object
#  39  TP_LINGUA               600000 non-null  int64
#  40  TX_GABARITO_CN          449009 non-null  object
#  41  TX_GABARITO_CH          469211 non-null  object
#  42  TX_GABARITO_LC          469211 non-null  object
#  43  TX_GABARITO_MT          449009 non-null  object
#  44  TP_STATUS_REDACAO       469211 non-null  float64
#  45  NU_NOTA_COMP1           469211 non-null  float64
#  46  NU_NOTA_COMP2           469211 non-null  float64
#  47  NU_NOTA_COMP3           469211 non-null  float64
#  48  NU_NOTA_COMP4           469211 non-null  float64
#  49  NU_NOTA_COMP5           469211 non-null  float64
#  50  NU_NOTA_REDACAO         469211 non-null  float64
#  51  Q001                    600000 non-null  object
#  52  Q002                    600000 non-null  object
#  53  Q003                    600000 non-null  object
#  54  Q004                    600000 non-null  object
#  55  Q005                    600000 non-null  float64
#  56  Q006                    600000 non-null  object
#  57  Q007                    600000 non-null  object
#  58  Q008                    600000 non-null  object
#  59  Q009                    600000 non-null  object
#  60  Q010                    600000 non-null  object
#  61  Q011                    600000 non-null  object
#  62  Q012                    600000 non-null  object
#  63  Q013                    600000 non-null  object
#  64  Q014                    600000 non-null  object
#  65  Q015                    600000 non-null  object
#  66  Q016                    600000 non-null  object
#  67  Q017                    600000 non-null  object
#  68  Q018                    600000 non-null  object
#  69  Q019                    600000 non-null  object
#  70  Q020                    600000 non-null  object
#  71  Q021                    600000 non-null  object
#  72  Q022                    600000 non-null  object
#  73  Q023                    600000 non-null  object
#  74  Q024                    600000 non-null  object
#  75  Q025                    600000 non-null  object
# dtypes: float64(22), int64(17), object(37)
# memory usage: 347.9+ MB
# None

# %% [markdown]
# ## **Verificando valores nulos nas colunas**

# %%
print("Valores nulos por coluna:")
nulos = df.isnull().sum()
print(nulos[nulos > 0])
# Out:
# Valores nulos por coluna:
# TP_ENSINO                 361074
# CO_MUNICIPIO_ESC          447903
# NO_MUNICIPIO_ESC          447903
# CO_UF_ESC                 447903
# SG_UF_ESC                 447903
# TP_DEPENDENCIA_ADM_ESC    447903
# TP_LOCALIZACAO_ESC        447903
# TP_SIT_FUNC_ESC           447903
# CO_PROVA_CN               150991
# CO_PROVA_CH               130789
# CO_PROVA_LC               130789
# CO_PROVA_MT               150991
# NU_NOTA_CN                150991
# NU_NOTA_CH                130789
# NU_NOTA_LC                130789
# NU_NOTA_MT                150991
# TX_RESPOSTAS_CN           150991
# TX_RESPOSTAS_CH           130789
# TX_RESPOSTAS_LC           130789
# TX_RESPOSTAS_MT           150991
# TX_GABARITO_CN            150991
# TX_GABARITO_CH            130789
# TX_GABARITO_LC            130789
# TX_GABARITO_MT            150991
# TP_STATUS_REDACAO         130789
# NU_NOTA_COMP1             130789
# NU_NOTA_COMP2             130789
# NU_NOTA_COMP3             130789
# NU_NOTA_COMP4             130789
# NU_NOTA_COMP5             130789
# NU_NOTA_REDACAO           130789
# dtype: int64

# %% [markdown]
# ## **Verificando valores únicos nas colunas**

# %%
print("Valores únicos nas colunas:")
df.nunique(dropna=False)
# Out:
# Valores únicos nas colunas:
# NU_INSCRICAO       600000
# NU_ANO                  3
# TP_FAIXA_ETARIA        20
# TP_SEXO                 2
# TP_ESTADO_CIVIL         5
#                     ...
# Q021                    2
# Q022                    5
# Q023                    2
# Q024                    5
# Q025                    2
# Length: 76, dtype: int64

# %% [markdown]
# ## **Transformação da coluna Q005**

# %%
print("Valores únicos da coluna 'Q005': \n", df['Q005'].unique())
print("Coluna Q005")
print(df['Q005'].head(5))
# Out:
# Valores únicos da coluna 'Q005':
#  [ 3.  6.  4.  1.  2.  5.  7.  8. 12.  9. 10. 20. 11. 15. 13. 18. 14. 17.
#  16. 19.]
# Coluna Q005
# 0    3.0
# 1    3.0
# 2    3.0
# 3    6.0
# 4    4.0
# Name: Q005, dtype: float64

# %% [markdown]
# A coluna Q005 refere-se ao número de pessoas na residência. Os valores NaN serão preenchidos com 1 e a coluna convertida para inteiro. O nome será alterado para 'qtde_pessoas_casa'.

# %%
df['Q005'] = df['Q005'].fillna(1).astype(int)

print("Coluna Q005")
print(df['Q005'].head(5))
print("Valores únicos da coluna 'Q005': \n", df['Q005'].unique())
# Out:
# Coluna Q005
# 0    3
# 1    3
# 2    3
# 3    6
# 4    4
# Name: Q005, dtype: int64
# Valores únicos da coluna 'Q005':
#  [ 3  6  4  1  2  5  7  8 12  9 10 20 11 15 13 18 14 17 16 19]

# %%
df.rename(columns={'Q005': 'qtde_pessoas_casa'}, inplace=True)
print("Coluna qtde_pessoas_casa")
print(df['qtde_pessoas_casa'].head(5))
# Out:
# Coluna qtde_pessoas_casa
# 0    3
# 1    3
# 2    3
# 3    6
# 4    4
# Name: qtde_pessoas_casa, dtype: int64

# %% [markdown]
# ## **Transformação da coluna Q011**

# %%
print("Valores únicos da coluna 'Q011': \n", df['Q011'].unique())
print("Coluna Q011")
print(df['Q011'].head(5))
# Out:
# Valores únicos da coluna 'Q011':
#  ['A' 'B' 'C' 'D' 'E']
# Coluna Q011
# 0    A
# 1    A
# 2    A
# 3    A
# 4    A
# Name: Q011, dtype: object

# %% [markdown]
# A coluna Q011 questiona sobre a posse de motocicleta na residência. Valores NaN serão tratados como 'Não informado'. As respostas (A, B, C, D, E) serão mapeadas para suas descrições completas (Não, Sim uma, Sim duas, etc.), conforme o dicionário do INEP. O nome da coluna será alterado para 'tem_motocicleta'.

# %%
dicio_moto = {
    'A': 'Não',
    'B': 'Sim, uma',
    'C': 'Sim, duas',
    'D': 'Sim, três',
    'E': 'Sim, quatro ou mais',
    'Não informado': 'Não informado'
}

df['Q011'] = df['Q011'].fillna('Não informado')
df['Q011'] = df['Q011'].map(dicio_moto)

print("Coluna Q011")
print(df['Q011'].head(5))
print("Valores únicos da coluna 'Q011': \n", df['Q011'].unique())
# Out:
# Coluna Q011
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# Name: Q011, dtype: object
# Valores únicos da coluna 'Q011':
#  ['Não' 'Sim, uma' 'Sim, duas' 'Sim, três' 'Sim, quatro ou mais']

# %%
df.rename(columns={'Q011': 'tem_motocicleta'}, inplace=True)
print("Coluna tem_motocicleta")
print(df['tem_motocicleta'].head(5))
# Out:
# Coluna tem_motocicleta
# 0    Não
# 1    Não
# 2    Não
# 3    Não
# 4    Não
# Name: tem_motocicleta, dtype: object

# %% [markdown]
# ## **Transformação da coluna Q025**

# %%
print("Valores únicos da coluna 'Q025': \n", df['Q025'].unique())
print("Coluna Q025")
print(df['Q025'].head(5))
# Out:
# Valores únicos da coluna 'Q025':
#  ['B' 'A']
# Coluna Q025
# 0    B
# 1    A
# 2    B
# 3    B
# 4    B
# Name: Q025, dtype: object

# %% [markdown]
# A coluna Q025 indica acesso à Internet na residência. Valores NaN serão tratados como 'Não informado'. Mapearemos 'A' para 'Não' e 'B' para 'Sim'. O nome da coluna será alterado para 'tem_internet'.

# %%
dicio_internet = {
    'A': 'Não',
    'B': 'Sim',
    'Não informado': 'Não informado'
}

df['Q025'] = df['Q025'].fillna('Não informado')
df['Q025'] = df['Q025'].map(dicio_internet)

print("Coluna Q025")
print(df['Q025'].head(5))
print("Valores únicos da coluna 'Q025': \n", df['Q025'].unique())
# Out:
# Coluna Q025
# 0    Sim
# 1    Não
# 2    Sim
# 3    Sim
# 4    Sim
# Name: Q025, dtype: object
# Valores únicos da coluna 'Q025':
#  ['Sim' 'Não']

# %%
df.rename(columns={'Q025': 'tem_internet'}, inplace=True)
print("Coluna tem_internet")
print(df['tem_internet'].head(5))
# Out:
# Coluna tem_internet
# 0    Sim
# 1    Não
# 2    Sim
# 3    Sim
# 4    Sim
# Name: tem_internet, dtype: object
